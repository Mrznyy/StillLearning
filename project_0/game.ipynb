# %%
import game_v2

game_v2.score_game(game_v2.random_predict)
# Out:
# Ваш алгоритм угадывает число в среднем за: 101 попыток
# 101

# %%
from game_v2 import score_game, random_predict
score_game(random_predict) #вызов функции
# Out:
# Ваш алгоритм угадывает число в среднем за: 101 попыток
# 101

# %% [markdown]
# git config --global user.name "Name"
# git config --global user.email email@example.ru
# Если вы захотите поменять информацию, то нужно будет ввести ту же команду, только без  --global.

# %% [markdown]
# # 1 уровень заголовок Игра угадай число
# ## 2  уровень Угадываем рандомно:
